# %%
# %matplotlib inline
#%matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,10)
from PIL import Image
import cv2
import linecache
import subprocess
import random
# Out:
# /home/lerrel/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from IPython.display import HTML

# %%
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # Visualization of conv_1 filters
# ## $complete-data$

# %%
root_path = '/media/lerrel/0A60802760801B97/Drone_Data/drone_script/training_progress/filtered_data/complete_data_filter/'
complete_fig_file_name = \
                ['filter_scratch_complete_dataset_complete_img_d_349_b_128_e_10_lr_0_05_wd_0_05.png', \
                 'filter_scratch_complete_dataset_complete_img_d_349_b_128_e_20_lr_0_05_wd_0_05.png', \
                 'filter_scratch_complete_dataset_complete_img_d_349_b_128_e_50_lr_0_05_wd_0_05.png', \
                 'filter_scratch_complete_dataset_complete_img_d_349_b_128_e_100_lr_0_05_wd_0_05.png', \
                 'filter_scratch_complete_dataset_complete_img_d_349_b_128_e_200_lr_0_05_wd_0_05.png', \
                 'filter_scratch_complete_dataset_complete_img_d_349_b_128_e_300_lr_0_05_wd_0_05.png', \
                ]
filtered_fig_file_name = \
                ['filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_10_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_20_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_50_lr_0_05_wd_0_05.png' ,\
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_100_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_200_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_300_lr_0_05_wd_0_05.png',\
                ]
epoch = [10,20,50,100,200,300]
plt.rcParams['figure.figsize'] = (10,10)
num_img_vis = 6
fig = plt.figure()
j = 1
for i in range(num_img_vis):
    title =  str(epoch[i]) + 'epoch'
    plt.title(title,fontsize=20)
    im = cv2.imread(root_path + complete_fig_file_name[i])
    plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
    plt.show()

# %% [markdown]
# ## $filtered-data$

# %%
root_path = '/media/lerrel/0A60802760801B97/Drone_Data/drone_script/training_progress/filtered_data/complete_data_filter/'
filtered_fig_file_name = \
                ['filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_10_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_20_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_50_lr_0_05_wd_0_05.png' ,\
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_100_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_200_lr_0_05_wd_0_05.png', \
                 'filter_scratch_filtered_dataset_complete_img_d_349_b_128_e_300_lr_0_05_wd_0_05.png',\
                ]
epoch = [10,20,50,100,200,300]
plt.rcParams['figure.figsize'] = (10,10)
num_img_vis = 6
fig = plt.figure()
j = 1
for i in range(num_img_vis):
    title =  str(epoch[i]) + 'epoch'
    plt.title(title,fontsize=20)
    im = cv2.imread(root_path + filtered_fig_file_name[i])
    plt.imshow(cv2.cvtColor(im,cv2.COLOR_BGR2RGB))
    plt.show()
